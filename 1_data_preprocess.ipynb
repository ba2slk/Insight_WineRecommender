# %% [markdown]
# <a href="https://colab.research.google.com/github/ba2slk/Insight_WineRecommender/blob/sangho/1_data_preprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tqdm import tqdm
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Import required libraries
import os
import zipfile
from urllib.request import urlretrieve

# Define dataset URL and filename
url = 'http://files.grouplens.org/datasets/movielens/ml-100k.zip'
filename = 'ml-100k.zip'

# Download the dataset
urlretrieve(url, filename)

# Unzip the downloaded file
with zipfile.ZipFile(filename, 'r') as zip_ref:
    zip_ref.extractall('.')

# Print confirmation message
print('MovieLens 100k dataset downloaded and unzipped!')
# Out:
# MovieLens 100k dataset downloaded and unzipped!

# %%
ratings = pd.read_csv(
    "./ml-100k/u.data",
    sep="\t",
    usecols=[0, 1, 2, 3],
    names=["user", "item", "rating", "time"],
)

# %%
ratings
# Out:
#        user  item  rating       time
# 0       196   242       3  881250949
# 1       186   302       3  891717742
# 2        22   377       1  878887116
# 3       244    51       2  880606923
# 4       166   346       1  886397596
# ...     ...   ...     ...        ...
# 99995   880   476       3  880175444
# 99996   716   204       5  879795543
# 99997   276  1090       1  874795795
# 99998    13   225       2  882399156
# 99999    12   203       3  879959583
#
# [100000 rows x 4 columns]

# %%
movies = pd.read_csv(
    "./ml-100k/u.item",
    sep="|",
    header=None,
    names=["movie_id", "title", "release_date", "video_release_date", "IMDb_URL",
           "unknown", "Action", "Adventure", "Animation", "Children's", "Comedy",
           "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror",
           "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"],
    encoding="latin-1"
)

# 전체 영화 ID 추출
all_items = movies['movie_id'].tolist()

# %% [markdown]
# 기본 통계
# * 유저, 아이템 수
# * 유저별 평가 수 등..

# %%
ratings.groupby('user').agg({'item': len}).agg({'item':[min, max, np.mean, len]})
# Out:
# <ipython-input-4-fc724746dc72>:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   ratings.groupby('user').agg({'item': len}).agg({'item':[min, max, np.mean, len]})
# <ipython-input-4-fc724746dc72>:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ratings.groupby('user').agg({'item': len}).agg({'item':[min, max, np.mean, len]})
# <ipython-input-4-fc724746dc72>:1: FutureWarning: The provided callable <function mean at 0x7d1ec25f95a0> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ratings.groupby('user').agg({'item': len}).agg({'item':[min, max, np.mean, len]})
#             item
# min    20.000000
# max   737.000000
# mean  106.044539
# len   943.000000

# %%
ratings.groupby('item').agg({'user': len}).agg({'user':[min, max, np.mean, len]})
# Out:
# <ipython-input-5-5d36fb3c2c06>:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   ratings.groupby('item').agg({'user': len}).agg({'user':[min, max, np.mean, len]})
# <ipython-input-5-5d36fb3c2c06>:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ratings.groupby('item').agg({'user': len}).agg({'user':[min, max, np.mean, len]})
# <ipython-input-5-5d36fb3c2c06>:1: FutureWarning: The provided callable <function mean at 0x7d1ec25f95a0> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ratings.groupby('item').agg({'user': len}).agg({'user':[min, max, np.mean, len]})
#              user
# min      1.000000
# max    583.000000
# mean    59.453032
# len   1682.000000

# %%
ratings.groupby('rating').agg({'item':len})
# Out:
#          item
# rating
# 1        6110
# 2       11370
# 3       27145
# 4       34174
# 5       21201

# %%
ratings.groupby('rating').agg({'item':len}).plot.bar()
# Out:
# <Axes: xlabel='rating'>

# %% [markdown]
# 전처리
# * user, item 인덱스 0부터 가공
# * explicit to implicit
# * train, val, test => 8 1 1

# %%
unique_users = ratings['user'].unique()
unique_items = ratings['item'].unique()

# %%
user2id = {user: idx for idx, user in enumerate(unique_users)}
id2user = {idx: user for idx, user in enumerate(unique_users)}

item2id = {item: idx for idx, item in enumerate(unique_items)}
id2item = {idx: item for idx, item in enumerate(unique_items)}

ratings['user'] = ratings['user'].map(user2id)
ratings['item'] = ratings['item'].map(item2id)

ratings
# Out:
#        user  item  rating       time
# 0         0     0       3  881250949
# 1         1     1       3  891717742
# 2         2     2       1  878887116
# 3         3     3       2  880606923
# 4         4     4       1  886397596
# ...     ...   ...     ...        ...
# 99995   875   173       3  880175444
# 99996   708   247       5  879795543
# 99997    37  1004       1  874795795
# 99998    58   443       2  882399156
# 99999   304   506       3  879959583
#
# [100000 rows x 4 columns]

# %%
ratings.loc[:, 'rating'] = 1

# %%
ratings
# Out:
#        user  item  rating       time
# 0         0     0       1  881250949
# 1         1     1       1  891717742
# 2         2     2       1  878887116
# 3         3     3       1  880606923
# 4         4     4       1  886397596
# ...     ...   ...     ...        ...
# 99995   875   173       1  880175444
# 99996   708   247       1  879795543
# 99997    37  1004       1  874795795
# 99998    58   443       1  882399156
# 99999   304   506       1  879959583
#
# [100000 rows x 4 columns]

# %%
ratings_sorted = ratings.sort_values(by=['user', 'time'])

# %%
# 각 유저별로 train, validation, test 데이터로 분할 (8:1:1 비율)
train, temp = train_test_split(ratings_sorted, test_size=0.2, stratify=ratings_sorted['user'], random_state=42)
val, test = train_test_split(temp, test_size=0.5, stratify=temp['user'], random_state=42)

# %%
len(ratings_sorted[ratings_sorted['user']==1]), len(train[train['user']==1]), len(val[val['user']==1]), len(test[test['user']==1])
# Out:
# (92, 74, 9, 9)

# %% [markdown]
# 저장

# %%
import pickle

# %%
result = {
    "train": train,
    "val" : val,
    "test" : test,
    "all_items": all_movies,
    "user2id" : user2id,
    "id2user" : id2user,
    "item2id" : item2id,
    "id2item" : id2item,
}

# %%
with open('ml-100k_splited.pkl', 'wb') as f:
    pickle.dump(result, f)

# %% [markdown]
# negative sampling 예시

# %%
all_movies = ratings['item'].unique()

users, items, labels = [], [], []

user_item_set = set(zip(train['user'], train['item']))

num_neg = 4

for u, i in tqdm(user_item_set):
    users.append(u)
    items.append(i)
    labels.append(1)
    for _ in range(num_neg):
        neg_item = np.random.choice(all_movies)
        while (u, neg_item) in user_item_set:
            neg_item = np.random.choice(all_movies)
        users.append(u)
        items.append(neg_item)
        labels.append(0)
# Out:
# 100%|██████████| 80000/80000 [00:05<00:00, 14537.10it/s]

# %%
list(zip(users, items, labels))
# Out:
# [(476, 78, 1),
#  (476, 935, 0),
#  (476, 379, 0),
#  (476, 512, 0),
#  (476, 270, 0),
#  (192, 319, 1),
#  (192, 1205, 0),
#  (192, 1193, 0),
#  (192, 1679, 0),
#  (192, 741, 0),
#  (782, 1316, 1),
#  (782, 52, 0),
#  (782, 1628, 0),
#  (782, 1264, 0),
#  (491, 951, 0),
#  (491, 1322, 0),
#  (491, 460, 0),
#  (491, 675, 0),
#  (546, 256, 1),
#  (546, 1296, 0),
#  (546, 605, 0),
#  (546, 1395, 0),
#  (546, 979, 0),
#  (257, 153, 1),
#  (257, 1624, 0),
#  (257, 3, 0),
#  (257, 1560, 0),
#  (257, 1213, 0),
#  (205, 717, 1),
#  (205, 1485, 0),
#  (205, 461, 0),
#  (205, 1338, 0),
#  (205, 299, 0),
#  (850, 1421, 1),
#  (850, 1500, 0),
#  (850, 226, 0),
#  (850, 932, 0),
#  (850, 349, 0),
#  (793, 887, 1),
#  (793, 252, 0),
#  (793, 503, 0),
#  (793, 1014, 0),
#  (793, 1249, 0),
#  (163, 491, 1),
#  (163, 722, 0),
#  (163, 905, 0),
#  (163, 96, 0),
#  (163, 1330, 0),
#  (9, 24, 1),
#  (9, 1366, 0),
#  (9, 215, 0),
#  (9, 1054, 0),
#  (9, 1526, 0),
#  (695, 729, 1),
#  (695, 1646, 0),
#  (695, 925, 0),
#  (695, 891, 0),
#  (695, 819, 0),
#  (748, 363, 1),
#  (748, 1007, 0),
#  (748, 1137, 0),
#  (748, 731, 0),
#  (748, 150, 0),
#  (63, 260, 1),
#  (63, 358, 0),
#  (63, 973, 0),
#  (63, 1659, 0),
#  (63, 1053, 0),
#  (692, 431, 1),
#  (692, 1109, 0),
#  (692, 351, 0),
#  (692, 581, 0),
#  (692, 1372, 0),
#  (465, 1206, 1),
#  (465, 57, 0),
#  (465, 446, 0),
#  (465, 468, 0),
#  (465, 1529, 0),
#  (499, 790, 1),
#  (499, 1464, 0),
#  (499, 888, 0),
#  (499, 618, 0),
#  (499, 392, 0),
#  (442, 256, 1),
#  (442, 1615, 0),
#  (442, 1663, 0),
#  (442, 1555, 0),
#  (442, 353, 0),
#  (158, 497, 1),
#  (158, 1187, 0),
#  (158, 1633, 0),
#  (158, 323, 0),
#  (158, 872, 0),
#  (402, 857, 1),
#  (402, 691, 0),
#  (402, 588, 0),
#  (402, 167, 0),
#  (402, 1565, 0),
#  (405, 374, 1),
#  (405, 1414, 0),
#  (405, 1601, 0),
#  (405, 905, 0),
#  (405, 635, 0),
#  (837, 31, 1),
#  (837, 1231, 0),
#  (837, 1431, 0),
#  (837, 1007, 0),
#  (837, 1255, 0),
#  (214, 806, 1),
#  (214, 813, 0),
#  (214, 648, 0),
#  (214, 1653, 0),
#  (214, 1484, 0),
#  (892, 492, 1),
#  (892, 635, 0),
#  (892, 937, 0),
#  (892, 980, 0),
#  (892, 1582, 0),
#  (501, 82, 1),
#  (501, 1407, 0),
#  (501, 1374, 0),
#  (501, 1290, 0),
#  (501, 1060, 0),
#  (649, 734, 1),
#  (649, 938, 0),
#  (649, 26, 0),
#  (649, 1495, 0),
#  (649, 1301, 0),
#  (248, 390, 1),
#  (248, 911, 0),
#  (248, 1161, 0),
#  (248, 1076, 0),
#  (248, 358, 0),
#  (456, 339, 1),
#  (456, 136, 0),
#  (456, 850, 0),
#  (456, 1182, 0),
#  (456, 683, 0),
#  (646, 436, 1),
#  (646, 1261, 0),
#  (646, 1188, 0),
#  (646, 177, 0),
#  (646, 622, 0),
#  (20, 159, 1),
#  (20, 38, 0),
#  (20, 447, 0),
#  (20, 870, 0),
#  (20, 188, 0),
#  (856, 431, 1),
#  (856, 1203, 0),
#  (856, 1114, 0),
#  (856, 1551, 0),
#  (856, 1353, 0),
#  (116, 621, 1),
#  (116, 141, 0),
#  (116, 747, 0),
#  (116, 277, 0),
#  (116, 1578, 0),
#  (892, 842, 1),
#  (892, 238, 0),
#  (892, 884, 0),
#  (892, 182, 0),
#  (892, 854, 0),
#  (694, 103, 1),
#  (694, 242, 0),
#  (694, 1382, 0),
#  (694, 1153, 0),
#  (694, 341, 0),
#  (35, 1221, 1),
#  (35, 1496, 0),
#  (35, 511, 0),
#  (35, 887, 0),
#  (35, 1255, 0),
#  (19, 688, 1),
#  (19, 519, 0),
#  (19, 1499, 0),
#  (19, 44, 0),
#  (19, 1317, 0),
#  (358, 154, 1),
#  (358, 250, 0),
#  (358, 1645, 0),
#  (358, 26, 0),
#  (358, 1555, 0),
#  (110, 52, 1),
#  (110, 1480, 0),
#  (110, 992, 0),
#  (110, 1099, 0),
#  (110, 637, 0),
#  (886, 273, 1),
#  (886, 298, 0),
#  (886, 1452, 0),
#  (886, 696, 0),
#  (886, 1603, 0),
#  (793, 82, 1),
#  (793, 1534, 0),
#  (793, 75, 0),
#  (793, 1603, 0),
#  (793, 777, 0),
#  (607, 858, 1),
#  (607, 309, 0),
#  (607, 574, 0),
#  (607, 523, 0),
#  (607, 89, 0),
#  (412, 390, 1),
#  (412, 1363, 0),
#  (412, 625, 0),
#  (412, 1230, 0),
#  (412, 1190, 0),
#  (71, 97, 1),
#  (71, 1170, 0),
#  (71, 1465, 0),
#  (71, 1158, 0),
#  (71, 210, 0),
#  (310, 113, 1),
#  (310, 1384, 0),
#  (310, 1529, 0),
#  (310, 1658, 0),
#  (310, 737, 0),
#  (375, 508, 1),
#  (375, 806, 0),
#  (375, 1376, 0),
#  (375, 1231, 0),
#  (375, 149, 0),
#  (26, 354, 1),
#  (26, 696, 0),
#  (26, 743, 0),
#  (26, 1279, 0),
#  (26, 1207, 0),
#  (937, 211, 1),
#  (937, 589, 0),
#  (937, 893, 0),
#  (937, 720, 0),
#  (937, 407, 0),
#  (23, 56, 1),
#  (23, 1075, 0),
#  (23, 1503, 0),
#  (23, 455, 0),
#  (23, 799, 0),
#  (413, 211, 1),
#  (413, 1526, 0),
#  (413, 1018, 0),
#  (413, 298, 0),
#  (413, 762, 0),
#  (845, 622, 1),
#  (845, 292, 0),
#  (845, 79, 0),
#  (845, 749, 0),
#  (845, 1093, 0),
#  (64, 57, 1),
#  (64, 723, 0),
#  (64, 1469, 0),
#  (64, 836, 0),
#  (64, 28, 0),
#  (129, 452, 1),
#  (129, 215, 0),
#  (129, 141, 0),
#  (129, 684, 0),
#  (129, 348, 0),
#  (27, 175, 1),
#  (27, 984, 0),
#  (27, 1097, 0),
#  (27, 96, 0),
#  (27, 1614, 0),
#  (402, 52, 1),
#  (402, 1270, 0),
#  (402, 925, 0),
#  (402, 1300, 0),
#  (402, 486, 0),
#  (426, 446, 1),
#  (426, 745, 0),
#  (426, 263, 0),
#  (426, 966, 0),
#  (426, 1284, 0),
#  (897, 31, 1),
#  (897, 1414, 0),
#  (897, 1227, 0),
#  (897, 1469, 0),
#  (897, 1589, 0),
#  (654, 273, 1),
#  (654, 378, 0),
#  (654, 105, 0),
#  (654, 637, 0),
#  (654, 1485, 0),
#  (573, 873, 1),
#  (573, 209, 0),
#  (573, 516, 0),
#  (573, 1353, 0),
#  (573, 1071, 0),
#  (516, 339, 1),
#  (516, 920, 0),
#  (516, 493, 0),
#  (516, 1422, 0),
#  (516, 1182, 0),
#  (172, 529, 1),
#  (172, 946, 0),
#  (172, 1256, 0),
#  (172, 1679, 0),
#  (172, 319, 0),
#  (526, 1027, 1),
#  (526, 300, 0),
#  (526, 1071, 0),
#  (526, 126, 0),
#  (526, 805, 0),
#  (180, 390, 1),
#  (180, 699, 0),
#  (180, 66, 0),
#  (180, 1205, 0),
#  (180, 1038, 0),
#  (328, 288, 1),
#  (328, 864, 0),
#  (328, 935, 0),
#  (328, 1560, 0),
#  (328, 1648, 0),
#  (367, 216, 1),
#  (367, 402, 0),
#  (367, 442, 0),
#  (367, 1600, 0),
#  (367, 1459, 0),
#  (804, 217, 1),
#  (804, 617, 0),
#  (804, 312, 0),
#  (804, 31, 0),
#  (804, 1517, 0),
#  (88, 801, 1),
#  (88, 1209, 0),
#  (88, 1135, 0),
#  (88, 1613, 0),
#  (88, 434, 0),
#  (231, 355, 1),
#  (231, 166, 0),
#  (231, 1573, 0),
#  (231, 151, 0),
#  (231, 409, 0),
#  (802, 144, 1),
#  (802, 97, 0),
#  (802, 609, 0),
#  (802, 1076, 0),
#  (802, 1560, 0),
#  (421, 452, 1),
#  (421, 1462, 0),
#  (421, 1232, 0),
#  (421, 1128, 0),
#  (421, 451, 0),
#  (238, 745, 1),
#  (238, 1466, 0),
#  (238, 1151, 0),
#  (238, 1257, 0),
#  (238, 958, 0),
#  (608, 278, 1),
#  (608, 589, 0),
#  (608, 1490, 0),
#  (608, 1003, 0),
#  (608, 1041, 0),
#  (35, 416, 1),
#  (35, 1271, 0),
#  (35, 138, 0),
#  (35, 906, 0),
#  (35, 1498, 0),
#  (379, 226, 1),
#  (379, 1602, 0),
#  (379, 47, 0),
#  (379, 316, 0),
#  (379, 972, 0),
#  (37, 462, 1),
#  (37, 856, 0),
#  (37, 932, 0),
#  (37, 1251, 0),
#  (37, 1435, 0),
#  (138, 514, 1),
#  (138, 1246, 0),
#  (138, 613, 0),
#  (138, 1504, 0),
#  (138, 1047, 0),
#  (630, 976, 1),
#  (630, 288, 0),
#  (630, 891, 0),
#  (630, 439, 0),
#  (630, 510, 0),
#  (661, 289, 1),
#  (661, 131, 0),
#  (661, 1102, 0),
#  (661, 1642, 0),
#  (661, 1483, 0),
#  ...]
